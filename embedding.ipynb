# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
import numpy as np
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
## test sentences
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good Developer',
    'Understand the meaning of words',
    'your videos are good'
]

# %%
voc_size = 10000

# %%
one_hot_rep = [one_hot(words, voc_size) for words in sent]
one_hot_rep
# Out:
# [[4501, 5779, 5892, 2812],
#  [4501, 5779, 5892, 3300],
#  [4501, 3263, 5892, 6927],
#  [4478, 2346, 9428, 1692, 5304],
#  [4478, 2346, 9428, 1692, 6224],
#  [9846, 4501, 3233, 5892, 3575],
#  [3328, 7963, 6238, 1692]]

# %%
sent_length = 8
embedded_doc = pad_sequences(one_hot_rep, sent_length, padding = 'pre')
embedded_doc
# Out:
# array([[   0,    0,    0,    0, 4501, 5779, 5892, 2812],
#        [   0,    0,    0,    0, 4501, 5779, 5892, 3300],
#        [   0,    0,    0,    0, 4501, 3263, 5892, 6927],
#        [   0,    0,    0, 4478, 2346, 9428, 1692, 5304],
#        [   0,    0,    0, 4478, 2346, 9428, 1692, 6224],
#        [   0,    0,    0, 9846, 4501, 3233, 5892, 3575],
#        [   0,    0,    0,    0, 3328, 7963, 6238, 1692]])

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.1)

# %%
dim = 10

# %%
model = Sequential()
embedding_layer = Embedding(input_dim=voc_size, output_dim=dim)
model.add(embedding_layer)
embedding_layer.build((None, sent_length))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)              │ (None, 8, 10)               │         100,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_doc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# array([[[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02631654, -0.01876124, -0.01110718, -0.00457488,
#           0.02497262, -0.01369584, -0.00361625,  0.04276669,
#           0.0121255 , -0.03842522],
#         [-0.00965584,  0.01593644,  0.03313876, -0.04432476,
#           0.00220167,  0.04390598, -0.04697065, -0.03633798,
#          -0.04450004,  0.03379237],
#         [-0.02556851, -0.00769719, -0.0451273 , -0.007705  ,
#          -0.00825907, -0.021023  ,  0.04600923, -0.01910703,
#           0.00866688,  0.03357336],
#         [ 0.04971998, -0.03883495,  0.00645109,  0.047823  ,
#          -0.04347624, -0.02658149,  0.0196433 , -0.00301672,
#          -0.04847504,  0.04612316]],
#
#        [[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02631654, -0.01876124, -0.01110718, -0.00457488,
#           0.02497262, -0.01369584, -0.00361625,  0.04276669,
#           0.0121255 , -0.03842522],
#         [-0.00965584,  0.01593644,  0.03313876, -0.04432476,
#           0.00220167,  0.04390598, -0.04697065, -0.03633798,
#          -0.04450004,  0.03379237],
#         [-0.02556851, -0.00769719, -0.0451273 , -0.007705  ,
#          -0.00825907, -0.021023  ,  0.04600923, -0.01910703,
#           0.00866688,  0.03357336],
#         [-0.03778915, -0.00721084,  0.0468588 ,  0.01766272,
#          -0.0237754 , -0.01705296, -0.04549969,  0.04696265,
#           0.03283842,  0.00570736]],
#
#        [[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02631654, -0.01876124, -0.01110718, -0.00457488,
#           0.02497262, -0.01369584, -0.00361625,  0.04276669,
#           0.0121255 , -0.03842522],
#         [-0.00892377,  0.0353446 , -0.01722505,  0.01929719,
#           0.03266635, -0.01627849,  0.03390494, -0.02887546,
#           0.00076245, -0.0359033 ],
#         [-0.02556851, -0.00769719, -0.0451273 , -0.007705  ,
#          -0.00825907, -0.021023  ,  0.04600923, -0.01910703,
#           0.00866688,  0.03357336],
#         [-0.04405689,  0.01917883,  0.03917042,  0.02366981,
#           0.02030816, -0.01840291,  0.0292976 , -0.01942209,
#           0.03669936, -0.03088092]],
#
#        [[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.01007702, -0.00346416, -0.0079302 , -0.01331381,
#           0.02245586, -0.01741654, -0.00870509,  0.03495191,
#          -0.03375621, -0.00714852],
#         [ 0.00708229,  0.02296721, -0.01594468,  0.00643778,
#           0.01817255,  0.02131362,  0.02368163,  0.0079615 ,
#           0.04711907, -0.0179571 ],
#         [ 0.04870884,  0.00778164,  0.01719164, -0.02265272,
#           0.04214584,  0.04969808, -0.01475848, -0.02825811,
#          -0.04414909, -0.02304154],
#         [ 0.04091135, -0.03599162, -0.03907657,  0.01791788,
#          -0.04479181, -0.03785951, -0.01214608,  0.00868016,
#          -0.03992437,  0.02177111],
#         [ 0.01291532,  0.00844936, -0.0034878 , -0.00102966,
#           0.03971788, -0.01197292,  0.02978304, -0.00157466,
#          -0.00972094,  0.0417532 ]],
#
#        [[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.01007702, -0.00346416, -0.0079302 , -0.01331381,
#           0.02245586, -0.01741654, -0.00870509,  0.03495191,
#          -0.03375621, -0.00714852],
#         [ 0.00708229,  0.02296721, -0.01594468,  0.00643778,
#           0.01817255,  0.02131362,  0.02368163,  0.0079615 ,
#           0.04711907, -0.0179571 ],
#         [ 0.04870884,  0.00778164,  0.01719164, -0.02265272,
#           0.04214584,  0.04969808, -0.01475848, -0.02825811,
#          -0.04414909, -0.02304154],
#         [ 0.04091135, -0.03599162, -0.03907657,  0.01791788,
#          -0.04479181, -0.03785951, -0.01214608,  0.00868016,
#          -0.03992437,  0.02177111],
#         [-0.04794883, -0.01897728,  0.01731661, -0.02260233,
#           0.04598418, -0.0133773 ,  0.00256205,  0.03711773,
#           0.04707811, -0.04574623]],
#
#        [[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.04017652, -0.02187001,  0.02373955, -0.03016954,
#           0.02268134,  0.00660565,  0.03075216,  0.02312083,
#          -0.01585106,  0.04644595],
#         [-0.02631654, -0.01876124, -0.01110718, -0.00457488,
#           0.02497262, -0.01369584, -0.00361625,  0.04276669,
#           0.0121255 , -0.03842522],
#         [ 0.00618045, -0.03344806,  0.03715166,  0.02842664,
#          -0.02242613, -0.01621584,  0.01610504,  0.01079872,
#          -0.03695501,  0.00510712],
#         [-0.02556851, -0.00769719, -0.0451273 , -0.007705  ,
#          -0.00825907, -0.021023  ,  0.04600923, -0.01910703,
#           0.00866688,  0.03357336],
#         [-0.04567598,  0.00739979, -0.04006871, -0.02401503,
#          -0.02843804,  0.00426203, -0.04119692,  0.01090741,
#          -0.04717947,  0.03849209]],
#
#        [[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.04613836, -0.02438536,  0.0251214 ,  0.03049973,
#          -0.03878193, -0.03581219, -0.03431118, -0.0435197 ,
#           0.04512307, -0.01801616],
#         [-0.03471534,  0.02827572, -0.02734474,  0.01488413,
#          -0.02955507,  0.0299424 , -0.03362717, -0.03998735,
#           0.04242237, -0.01060734],
#         [ 0.01318414, -0.0334108 ,  0.00424626,  0.00906385,
#           0.02459086,  0.04395084, -0.02270625, -0.04233427,
#           0.01441297, -0.01970743],
#         [ 0.04091135, -0.03599162, -0.03907657,  0.01791788,
#          -0.04479181, -0.03785951, -0.01214608,  0.00868016,
#          -0.03992437,  0.02177111]]], dtype=float32)

# %%
embedded_doc[0]
# Out:
# array([   0,    0,    0,    0, 4501, 5779, 5892, 2812])

# %%
single_input = np.expand_dims(embedded_doc[0], axis=0)

# %%
model.predict(single_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# array([[[-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02550524, -0.03034973, -0.01113306, -0.02560756,
#          -0.03275429, -0.04236194, -0.03500264,  0.01230841,
#           0.01522477, -0.04113315],
#         [-0.02631654, -0.01876124, -0.01110718, -0.00457488,
#           0.02497262, -0.01369584, -0.00361625,  0.04276669,
#           0.0121255 , -0.03842522],
#         [-0.00965584,  0.01593644,  0.03313876, -0.04432476,
#           0.00220167,  0.04390598, -0.04697065, -0.03633798,
#          -0.04450004,  0.03379237],
#         [-0.02556851, -0.00769719, -0.0451273 , -0.007705  ,
#          -0.00825907, -0.021023  ,  0.04600923, -0.01910703,
#           0.00866688,  0.03357336],
#         [ 0.04971998, -0.03883495,  0.00645109,  0.047823  ,
#          -0.04347624, -0.02658149,  0.0196433 , -0.00301672,
#          -0.04847504,  0.04612316]]], dtype=float32)
