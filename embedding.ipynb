# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
import numpy as np
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
## test sentences
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good Developer',
    'Understand the meaning of words',
    'your videos are good'
]

# %%
voc_size = 10000

# %%
one_hot_rep = [one_hot(words, voc_size) for words in sent]
one_hot_rep
# Out:
# [[4501, 5779, 5892, 2812],
#  [4501, 5779, 5892, 3300],
#  [4501, 3263, 5892, 6927],
#  [4478, 2346, 9428, 1692, 5304],
#  [4478, 2346, 9428, 1692, 6224],
#  [9846, 4501, 3233, 5892, 3575],
#  [3328, 7963, 6238, 1692]]

# %%
max_sent_length = 8
embedded_doc = pad_sequences(one_hot_rep, max_sent_length, padding = 'pre')
embedded_doc
# Out:
# array([[   0,    0,    0,    0, 4501, 5779, 5892, 2812],
#        [   0,    0,    0,    0, 4501, 5779, 5892, 3300],
#        [   0,    0,    0,    0, 4501, 3263, 5892, 6927],
#        [   0,    0,    0, 4478, 2346, 9428, 1692, 5304],
#        [   0,    0,    0, 4478, 2346, 9428, 1692, 6224],
#        [   0,    0,    0, 9846, 4501, 3233, 5892, 3575],
#        [   0,    0,    0,    0, 3328, 7963, 6238, 1692]])

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.1)

# %%
word_dim = 10

# %%
model = Sequential()
embedding_layer = Embedding(input_dim=voc_size, output_dim=word_dim)
model.add(embedding_layer)
embedding_layer.build((None, sent_length))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)              │ (None, 8, 10)               │         100,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_doc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# array([[[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.00850974,  0.01504571,  0.01397857, -0.04893384,
#           0.03702382, -0.03282566, -0.03311589, -0.02649988,
#          -0.02301209,  0.01830358],
#         [ 0.02692709,  0.00456178, -0.02060453,  0.04791978,
#           0.00146275, -0.01279926,  0.04570771,  0.04541358,
#          -0.03051368,  0.02753944],
#         [-0.03422552, -0.0104141 , -0.02939867,  0.04572889,
#          -0.02426316,  0.04758867, -0.04010686,  0.00999855,
#          -0.04073576, -0.03914868],
#         [ 0.002168  ,  0.02090024,  0.00986012, -0.00182214,
#          -0.00794237,  0.02609957, -0.00410734,  0.03858929,
#           0.0179574 ,  0.02235646]],
#
#        [[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.00850974,  0.01504571,  0.01397857, -0.04893384,
#           0.03702382, -0.03282566, -0.03311589, -0.02649988,
#          -0.02301209,  0.01830358],
#         [ 0.02692709,  0.00456178, -0.02060453,  0.04791978,
#           0.00146275, -0.01279926,  0.04570771,  0.04541358,
#          -0.03051368,  0.02753944],
#         [-0.03422552, -0.0104141 , -0.02939867,  0.04572889,
#          -0.02426316,  0.04758867, -0.04010686,  0.00999855,
#          -0.04073576, -0.03914868],
#         [ 0.01779172,  0.04488511, -0.02131289,  0.02442685,
#          -0.03782665, -0.03302965, -0.02141767, -0.02605232,
#           0.0380273 ,  0.01389985]],
#
#        [[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.00850974,  0.01504571,  0.01397857, -0.04893384,
#           0.03702382, -0.03282566, -0.03311589, -0.02649988,
#          -0.02301209,  0.01830358],
#         [-0.02649283,  0.03517313,  0.0168271 ,  0.0192926 ,
#           0.00613161,  0.04782113, -0.02543155,  0.04983181,
#           0.04243941, -0.00523076],
#         [-0.03422552, -0.0104141 , -0.02939867,  0.04572889,
#          -0.02426316,  0.04758867, -0.04010686,  0.00999855,
#          -0.04073576, -0.03914868],
#         [-0.02820723, -0.02429622, -0.01585243, -0.01590221,
#           0.04729588,  0.00790524, -0.02165365,  0.04274395,
#           0.03356921, -0.03067336]],
#
#        [[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.0486065 , -0.03135051,  0.03631315,  0.01164781,
#          -0.0153036 ,  0.01356492,  0.02787146,  0.00990795,
#           0.01546054,  0.01235359],
#         [ 0.01417485, -0.03093417, -0.02810138,  0.02076762,
#           0.03603318, -0.0075423 , -0.00797523,  0.04421461,
#          -0.00550174, -0.02635993],
#         [-0.00991967,  0.00628644, -0.02052494,  0.00921774,
#           0.04301406,  0.02910152, -0.02104321, -0.02462497,
#          -0.04066906, -0.03712275],
#         [-0.00122482, -0.04025462, -0.01864575,  0.01811961,
#           0.02326984, -0.03235085,  0.04554135, -0.04870541,
#           0.03950211, -0.02341248],
#         [ 0.04119634,  0.00765599, -0.00626542, -0.04939632,
#          -0.01997261, -0.03549321, -0.04768912,  0.00945278,
#           0.00334705,  0.0066605 ]],
#
#        [[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.0486065 , -0.03135051,  0.03631315,  0.01164781,
#          -0.0153036 ,  0.01356492,  0.02787146,  0.00990795,
#           0.01546054,  0.01235359],
#         [ 0.01417485, -0.03093417, -0.02810138,  0.02076762,
#           0.03603318, -0.0075423 , -0.00797523,  0.04421461,
#          -0.00550174, -0.02635993],
#         [-0.00991967,  0.00628644, -0.02052494,  0.00921774,
#           0.04301406,  0.02910152, -0.02104321, -0.02462497,
#          -0.04066906, -0.03712275],
#         [-0.00122482, -0.04025462, -0.01864575,  0.01811961,
#           0.02326984, -0.03235085,  0.04554135, -0.04870541,
#           0.03950211, -0.02341248],
#         [-0.04918   ,  0.0341334 ,  0.04263589,  0.02561544,
#           0.03242495,  0.02432713,  0.01154677,  0.0321059 ,
#          -0.04164363,  0.02397611]],
#
#        [[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.01254213,  0.02256704, -0.02090863, -0.04407729,
#           0.02762282, -0.04817001,  0.0064872 , -0.00532519,
#          -0.03173422, -0.00489675],
#         [ 0.00850974,  0.01504571,  0.01397857, -0.04893384,
#           0.03702382, -0.03282566, -0.03311589, -0.02649988,
#          -0.02301209,  0.01830358],
#         [-0.01138685,  0.03743428,  0.00829428, -0.01028129,
#          -0.04065644, -0.03563882, -0.03873723, -0.00669588,
#          -0.00832455, -0.03241494],
#         [-0.03422552, -0.0104141 , -0.02939867,  0.04572889,
#          -0.02426316,  0.04758867, -0.04010686,  0.00999855,
#          -0.04073576, -0.03914868],
#         [ 0.01559261, -0.03846313,  0.0107531 , -0.01301252,
#           0.01942788,  0.02091607,  0.00221398,  0.00243463,
#           0.02113274, -0.01541454]],
#
#        [[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.01682997, -0.00796073, -0.00146695, -0.00248919,
#          -0.0123288 , -0.01921238,  0.03072249,  0.00732322,
#          -0.02321808, -0.02191436],
#         [-0.03446951,  0.0004043 , -0.01548785, -0.02421231,
#          -0.02686708, -0.02994399, -0.04870764,  0.04766471,
#           0.02064471,  0.00812169],
#         [-0.01360394,  0.04148122, -0.01297027,  0.03331006,
#          -0.03431273, -0.03869796,  0.03246904,  0.02350109,
#           0.03449373,  0.0111043 ],
#         [-0.00122482, -0.04025462, -0.01864575,  0.01811961,
#           0.02326984, -0.03235085,  0.04554135, -0.04870541,
#           0.03950211, -0.02341248]]], dtype=float32)

# %%
embedded_doc[0]
# Out:
# array([   0,    0,    0,    0, 4501, 5779, 5892, 2812])

# %%
single_input = np.expand_dims(embedded_doc[0], axis=0)

# %%
model.predict(single_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# array([[[ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.03004456, -0.00408792, -0.04790777, -0.0473907 ,
#          -0.04843929, -0.00966102, -0.00485513,  0.0338115 ,
#          -0.04614064,  0.02610154],
#         [ 0.00850974,  0.01504571,  0.01397857, -0.04893384,
#           0.03702382, -0.03282566, -0.03311589, -0.02649988,
#          -0.02301209,  0.01830358],
#         [ 0.02692709,  0.00456178, -0.02060453,  0.04791978,
#           0.00146275, -0.01279926,  0.04570771,  0.04541358,
#          -0.03051368,  0.02753944],
#         [-0.03422552, -0.0104141 , -0.02939867,  0.04572889,
#          -0.02426316,  0.04758867, -0.04010686,  0.00999855,
#          -0.04073576, -0.03914868],
#         [ 0.002168  ,  0.02090024,  0.00986012, -0.00182214,
#          -0.00794237,  0.02609957, -0.00410734,  0.03858929,
#           0.0179574 ,  0.02235646]]], dtype=float32)
